# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewsJascoro/DataAnalyts_Mintic_Talento_Tech/blob/main/Data_Cleaning_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hello everyone overthere,**
#
# This is Javier A. S. Coronado.
# I made this colaboratory of name Data_Cleaning_Tutorial to Curso Análisis de Datos y Visualización to synchronous virtual course of Mintic, Talento Tech in Bogotá, Colombia February 2024.
#
# 1. **El problema del negocio**
#
# Una entidad bancaria contrata a una empresa de marketing encargada de contactar telefónicamente a posibles clientes para determinar si están interesados o no en adquirir un certificado de depósito a término con el banco.
#
# ***¿Qué perfil tienen los clientes con mayor potencial de conversión?***
#
# 2.  **El set de datos DataSet**
#
# La información recolectada por la empresa de mercadeo se encuentra en un archivo CSV (`dataset_banco.csv`) con 45215 filas y 17 columnas.
#
# Cada registro contiene 16 características (las primeras 16 columnas) y una categoría ("yes" o "no" dependiendo de si la persona está o no interesada en adquirir el producto). Las columnas son:
#
# 1. "age":  edad (numérica)
# 2. "job": tipo de trabajo (categórica: "admin.", "unknown", "unemployed", "management", "housemaid", "entrepreneur", "student", "blue-collar","self-employed", "retired", "technician", "services")
# 3. "marital": estado civil (categórica: "married", "divorced", "single")
# 4. "education": nivel educativo (categórica: "unknown", "secondary", "primary", "tertiary")
# 5. "default": si dejó de pagar sus obligaciones (categórica: "yes", "no")
# 6. "balance": saldo promedio anual en euros (numérica)
# 7. "housing": ¿tiene o no crédito hipotecario? (categórica: "yes", "no")
# 8. "loan": ¿tiene créditos de consumo? (categórica: "yes", "no")
# 9. "contact": medio a través del cual fue contactado (categórica: "unknown", "telephone", "cellular")
# 10. "day": último día del mes en el que fue contactada (numérica)
# 11. "month": último mes en el que fue contactada (categórica: "jan", "feb", "mar", ..., "nov", "dec")
# 12. "duration": duración (en segundos) del último contacto (numérica)
# 13. "campaign": número total de veces que fue contactada durante la campaña (numérica)
# 14. "pdays": número de días transcurridos después de haber sido contactado antes de la campaña actual (numérica. -1 indica que no fue contactado previamente)
# 15. "previous": número de veces que ha sido contactada antes de esta campaña (numérica)
# 16. "poutcome": resultado de la campaña de marketing anterior (categórica: "unknown", "other", "failure", "success")
# 17. "y": categoría ¿el cliente se suscribió a un depósito a término? (categórica: "yes", "no").
#
# ***#3. Una primera mirada al dataset***
#
# dataset: This refers to a Pandas DataFrame object. Pandas is a popular Python library used for data manipulation and analysis, and a DataFrame is a two-dimensional labeled data structure with columns that can be of different types.

# %%
# Reading
'''
from google.colab import drive
drive.mount('/content/drive')
path= "/content/drive/MyDrive/ColabNotebooks/Whatever_name_you_wanna_set_up.csv"
data = pd.read_csv(path)
'''
# Out:
# '\nfrom google.colab import drive\ndrive.mount(\'/content/drive\')\npath= "/content/drive/MyDrive/ColabNotebooks/Whatever_name_you_wanna_set_up.csv"\ndata = pd.read_csv(path)\n'

# %%
#3. Una primera mirada al dataset
#Librerias Import libreries to run code.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **#4. Limpieza**
#
# Realizaremos el proceso de limpieza teniendo en cuenta las situaciones más comunes:
#
# ***1. Datos faltantes en algunas celdas***
#
#
# We start with this line of code to show a part of our dataset.
#
#  **dataset.iloc[:6]**
#
#  This returns a new DataFrame containing only the first 6 rows of the original DataFrame dataset. It's a way to slice or subset the DataFrame based on row positions.

# %%
# Importar librerias import libraries to using in basic course.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# This is the name of csv file: dataset_banco_101.csv

dataset_banco_101 = "Put here your path: Whatever name and location (path), you wanna set up.csv"
#dataset = pd.read_csv(dataset_banco_101)
dataset.iloc[:6]  # Use iloc[] # This means it selects the first 6 rows of the DataFrame dataset.

# %% [markdown]
# ![One_Begins.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # Netx step:

# %% [markdown]
# 1. ***Missing data in some cells***
#
# **dataset.isna().sum()**
#
# Returns a Pandas Series object where each element represents the count of missing values in the corresponding column of the dataset DataFrame.
#
# **.isna():** This is a Pandas DataFrame method used to detect missing or NaN (Not a Number) values in the DataFrame. It returns a DataFrame of the same shape as the original DataFrame, where each element is either True (indicating a missing value) or False (indicating a non-missing value).
#
# It returns a DataFrame of the same shape as the original DataFrame, where each element is either True (indicating a missing value) or False (indicating a non-missing value).
#
# **.sum():** This is another DataFrame method, but when applied after .isna(), it sums up the True values for each column.

# %%
print(dataset.shape)
dataset.head()
dataset.info()
dataset.isna().sum() # This is a Pandas DataFrame method used to detect missing or NaN (Not a Number) values in the DataFrame.
#dataset.dropna()
dataset.info()
#dataset.dropna(inplace=True)
dataset.info()

# %%
# Assuming 'dataset' is my or your DataFrame
# Replace 'dataset' with the name of your DataFrame
# Count the number of missing values in each column
missing_values = dataset.isna().sum()
# Print the result
print("Number of missing values in each column:")
print(missing_values)
# This print out a Series object where the index represents the column names
# and the values represent the number of missing values in each column.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# If you want to know the total number of missing values in the entire DataFrame, you can use the **sum()** method again on the result:
#
# This is give you the total count of missing values in your DataFrame.

# %%
# Total number of missing values in the entire DataFrame
total_missing_values = missing_values.sum()
print("Total number of missing values in the entire DataFrame:", total_missing_values)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
